# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data=pd.read_csv(r"C:\Users\Jasum\Downloads\state_pop_by_age_gender.csv")
print(data)
x=data.gender_group
y=data.population
plt.bar(x,y,color='red')
plt.title("Distribution of Gender in Population.")
plt.xlabel("GENDER")
plt.ylabel("POPULATION")
plt.show()
# Out:
#     gender_group  population
# 0         Female      536918
# 1         Female     1979977
# 2         Female     2516895
# 3           Male      559458
# 4           Male     1799897
# ..           ...         ...
# 472         Male      225899
# 473         Male      296202
# 474         Both      136371
# 475         Both      444653
# 476         Both      581024
#
# [477 rows x 2 columns]
